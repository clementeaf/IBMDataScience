# %% [markdown]
# # Final Exam

# %% [markdown]
# ## This notebook is about to share new knowledge in the path of my carreer in Data Science

# %% [markdown]
# #### Data Science Languages:
#         1. Python
#         2. R
#         3. SQL
#         4. Java
#         5. Julia
#         6. Scala
#         7. C/C+
#         8. JavaScript

# %% [markdown]
# #### Data Science Libraries:
#        1. Numpy
#        2. Leaflet
#        3. ggplot2
#        4. Pandas
#        5. Matplotlib
#        6. Keras
#        7. Caret

# %% [markdown]
# | Data Science Tool |
# | --- |
# | SAS |
# | Apache Spark |
# | BigML |
# | Tableau |
# | TensowFlow |
# | Scikit-learn |

# %%
5 * 5
# Out:
# 25

# %%
num = input("Enter a number: ")
m = int(num) * 2
print(f"Double of {num}, is {m}".format(num, m))
# Out:
# Enter a number: 5
# Double of 5, is 10

# %%
minutes = input("Enter a number: ")
hour = int(int(minutes) / 60)
print(f"{hour} hours")
# Out:
# Enter a number: 120
# 2 hours

# %% [markdown]
# ### Objectives:
#       - List popular langagues for Data Science
#       - List popular libraries for Data Science
#       - Learn how to process data in Jupyter Notebooks
#       - Use RStudio and Python
#       - Be creative and curious

# %% [markdown]
# ##### Author: Clemente Arriagada F
